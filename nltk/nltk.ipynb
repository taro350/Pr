# %%
import numpy as np
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import requests
from bs4 import BeautifulSoup as bs

re = requests.get('https://en.wikipedia.org/wiki/SpaceX').text

soup = bs(re, 'html.parser')
text = soup.get_text(strip=True)

sw = stopwords.words('English')

token = [t for t in word_tokenize(text)]
token

# csv = pd.read_csv('Restaurant_Reviews.tsv')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['SpaceX',
#  '-',
#  'Wikipediadocument.documentElement.className=',
#  "''",
#  'client-js',
#  "''",
#  ';',
#  'RLCONF=',
#  '{',
#  '``',
#  'wgBreakFrames',
#  "''",
#  ':',
#  '!',
#  '1',
#  ',',
#  "''",
#  'wgSeparatorTransformTable',
#  "''",
#  ':',
#  '[',
#  '``',
#  "''",
#  ',',
#  "''",
#  "''",
#  ']',
#  ',',
#  "''",
#  'wgDigitTransformTable',
#  "''",
#  ':',
#  '[',
#  '``',
#  "''",
#  ',',
#  "''",
#  "''",
#  ']',
#  ',',
#  "''",
#  'wgDefaultDateFormat',
#  "''",
#  ':',
#  "''",
#  'dmy',
#  "''",
#  ',',
#  "''",
#  'wgMonthNames',
#  "''",
#  ':',
#  '[',
#  '``',
#  "''",
#  ',',
#  "''",
#  'January',
#  "''",
#  ',',
#  "''",
#  'February',
#  "''",
#  ',',
#  "''",
#  'March',
#  "''",
#  ',',
#  "''",
#  'April',
#  "''",
#  ',',
#  "''",
#  'May',
#  "''",
#  ',',
#  "''",
#  'June',
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

sid_obj = SentimentIntensityAnalyzer() 
sentiment_dict = sid_obj.polarity_scores("I am so sad right now because I didn't get the chance to see her in person")
sentiment_dict

sentiment_dict2 = sid_obj.polarity_scores("I am very happy right now because I beated him up!")
sentiment_dict2
# Out:
# {'neg': 0.0, 'neu': 0.651, 'pos': 0.349, 'compound': 0.6468}

# %%
url_list =[]
date_time = []
news_text = []
headlines = []



response = requests.get('https://oilprice.com/Energy').text
soup = bs.get_text(response, 'html.parser')
for link in soup.find_all("div", {class: 'categoryArticle'}):
    for info in soup.find_all("a"):
        if info.get('href') not in url_list:
            url_list.append(info.get('href'))

# %%
xs = [1, 2, 3]
lx = lambda x: x*x
ys = list(map(lx,xs))
print(ys)
print(sum(ys))
# Out:
# [1, 4, 9]
# 14

# %%
xs = [1, 2, 3]
lx = lambda x: x > 1
ys = list(map(lx,xs))
print(ys)
print(sum(ys))
# Out:
# [False, True, True]
# 2

# %%
A = 'https://oilprice.com/oil-price-charts'
a = A.split('/')
b = a[-1]
c = b.replace('-', ' ')
print(a)
print(b)
print(c)
# Out:
# ['https:', '', 'oilprice.com', 'oil-price-charts']
# oil-price-charts
# oil price charts
